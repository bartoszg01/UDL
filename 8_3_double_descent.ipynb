# %% [markdown]
# <a href="https://colab.research.google.com/github/bartoszg01/UDL/blob/main/8_3_double_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-oo8lohuu
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-oo8lohuu
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=22d2d0fb5650524afd74d36df91fad81476f1b2fbd7da695a6cfed898cd4ccb4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_h38ejwk/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.293982, train error 87.28,  test loss 2.291997, test error 86.80
# Epoch   100, train loss 1.906802, train error 71.75,  test loss 1.758760, test error 69.85
# Epoch   200, train loss 1.891950, train error 70.82,  test loss 1.736115, test error 69.03
# Epoch   300, train loss 1.886209, train error 71.18,  test loss 1.729980, test error 68.95
# Epoch   400, train loss 1.886428, train error 70.20,  test loss 1.729663, test error 68.95
# Epoch   500, train loss 1.884891, train error 70.88,  test loss 1.727719, test error 70.15
# Epoch   600, train loss 1.885944, train error 71.10,  test loss 1.730261, test error 70.05
# Epoch   700, train loss 1.880405, train error 70.32,  test loss 1.725157, test error 69.38
# Epoch   800, train loss 1.882625, train error 70.65,  test loss 1.726644, test error 69.22
# Epoch   900, train loss 1.879816, train error 70.78,  test loss 1.728872, test error 69.53
# Training model with   4 hidden variables
# Epoch     0, train loss 2.266817, train error 87.82,  test loss 2.254276, test error 87.22
# Epoch   100, train loss 1.773312, train error 65.28,  test loss 1.612850, test error 63.20
# Epoch   200, train loss 1.748266, train error 64.55,  test loss 1.601762, test error 62.33
# Epoch   300, train loss 1.741559, train error 64.82,  test loss 1.586619, test error 62.30
# Epoch   400, train loss 1.744435, train error 64.97,  test loss 1.596889, test error 63.12
# Epoch   500, train loss 1.743263, train error 64.40,  test loss 1.598132, test error 62.85
# Epoch   600, train loss 1.734990, train error 63.80,  test loss 1.598061, test error 62.58
# Epoch   700, train loss 1.733436, train error 64.35,  test loss 1.603042, test error 62.55
# Epoch   800, train loss 1.735213, train error 64.15,  test loss 1.602010, test error 62.60
# Epoch   900, train loss 1.733430, train error 63.88,  test loss 1.607088, test error 62.42
# Training model with   6 hidden variables
# Epoch     0, train loss 2.284486, train error 88.25,  test loss 2.282821, test error 87.43
# Epoch   100, train loss 1.663211, train error 59.45,  test loss 1.469731, test error 56.78
# Epoch   200, train loss 1.615966, train error 57.35,  test loss 1.413324, test error 54.15
# Epoch   300, train loss 1.600169, train error 57.58,  test loss 1.412465, test error 55.25
# Epoch   400, train loss 1.600878, train error 57.45,  test loss 1.414925, test error 54.50
# Epoch   500, train loss 1.590031, train error 57.03,  test loss 1.413028, test error 54.72
# Epoch   600, train loss 1.575405, train error 56.22,  test loss 1.404819, test error 53.97
# Epoch   700, train loss 1.576633, train error 56.50,  test loss 1.410173, test error 54.45
# Epoch   800, train loss 1.568404, train error 56.28,  test loss 1.409676, test error 54.45
# Epoch   900, train loss 1.570620, train error 56.65,  test loss 1.413329, test error 55.20
# Training model with   8 hidden variables
# Epoch     0, train loss 2.294598, train error 87.53,  test loss 2.296810, test error 87.05
# Epoch   100, train loss 1.585596, train error 54.30,  test loss 1.431803, test error 53.45
# Epoch   200, train loss 1.516065, train error 51.33,  test loss 1.350481, test error 50.22
# Epoch   300, train loss 1.490357, train error 51.10,  test loss 1.321043, test error 49.22
# Epoch   400, train loss 1.469070, train error 49.42,  test loss 1.301170, test error 48.60
# Epoch   500, train loss 1.460433, train error 49.33,  test loss 1.296853, test error 47.83
# Epoch   600, train loss 1.457618, train error 49.38,  test loss 1.304734, test error 47.62
# Epoch   700, train loss 1.451453, train error 48.62,  test loss 1.308913, test error 48.30
# Epoch   800, train loss 1.446222, train error 48.80,  test loss 1.310009, test error 47.78
# Epoch   900, train loss 1.444782, train error 48.50,  test loss 1.314824, test error 48.25
# Training model with  10 hidden variables
# Epoch     0, train loss 2.277646, train error 86.85,  test loss 2.269018, test error 85.97
# Epoch   100, train loss 1.576847, train error 55.70,  test loss 1.422707, test error 54.62
# Epoch   200, train loss 1.510863, train error 53.40,  test loss 1.415275, test error 52.60
# Epoch   300, train loss 1.481171, train error 52.30,  test loss 1.422687, test error 53.42
# Epoch   400, train loss 1.465983, train error 51.47,  test loss 1.419200, test error 52.90
# Epoch   500, train loss 1.456797, train error 51.47,  test loss 1.433048, test error 53.62
# Epoch   600, train loss 1.451920, train error 51.58,  test loss 1.451990, test error 53.67
# Epoch   700, train loss 1.444698, train error 51.22,  test loss 1.463682, test error 53.58
# Epoch   800, train loss 1.437889, train error 50.33,  test loss 1.481694, test error 53.38
# Epoch   900, train loss 1.434449, train error 50.83,  test loss 1.489012, test error 53.78
# Training model with  14 hidden variables
# Epoch     0, train loss 2.283356, train error 85.45,  test loss 2.277670, test error 85.72
# Epoch   100, train loss 1.456070, train error 49.83,  test loss 1.362142, test error 50.67
# Epoch   200, train loss 1.371017, train error 46.72,  test loss 1.334008, test error 50.12
# Epoch   300, train loss 1.335119, train error 45.33,  test loss 1.322358, test error 49.58
# Epoch   400, train loss 1.314457, train error 44.05,  test loss 1.331817, test error 49.70
# Epoch   500, train loss 1.305182, train error 43.75,  test loss 1.333460, test error 49.00
# Epoch   600, train loss 1.281018, train error 42.53,  test loss 1.336111, test error 48.55
# Epoch   700, train loss 1.282948, train error 42.78,  test loss 1.344393, test error 48.83
# Epoch   800, train loss 1.273407, train error 42.70,  test loss 1.339362, test error 48.75
# Epoch   900, train loss 1.269884, train error 42.90,  test loss 1.360536, test error 49.25
# Training model with  18 hidden variables
# Epoch     0, train loss 2.171013, train error 82.22,  test loss 2.134877, test error 80.90
# Epoch   100, train loss 1.414492, train error 47.78,  test loss 1.398139, test error 53.03
# Epoch   200, train loss 1.297588, train error 44.60,  test loss 1.388476, test error 51.38
# Epoch   300, train loss 1.250168, train error 42.65,  test loss 1.402494, test error 51.40
# Epoch   400, train loss 1.229104, train error 42.17,  test loss 1.431490, test error 50.65
# Epoch   500, train loss 1.215383, train error 41.62,  test loss 1.464594, test error 51.17
# Epoch   600, train loss 1.196865, train error 41.20,  test loss 1.492972, test error 52.10
# Epoch   700, train loss 1.184972, train error 40.50,  test loss 1.511780, test error 52.60
# Epoch   800, train loss 1.178436, train error 40.30,  test loss 1.533293, test error 53.38
# Epoch   900, train loss 1.171087, train error 39.83,  test loss 1.544106, test error 53.22
# Training model with  22 hidden variables
# Epoch     0, train loss 2.234640, train error 82.43,  test loss 2.209292, test error 80.80
# Epoch   100, train loss 1.261650, train error 41.40,  test loss 1.307891, test error 49.00
# Epoch   200, train loss 1.130033, train error 37.22,  test loss 1.353112, test error 48.80
# Epoch   300, train loss 1.085368, train error 35.70,  test loss 1.434460, test error 49.40
# Epoch   400, train loss 1.056718, train error 34.82,  test loss 1.505210, test error 50.40
# Epoch   500, train loss 1.038170, train error 34.62,  test loss 1.553189, test error 50.30
# Epoch   600, train loss 1.015726, train error 34.00,  test loss 1.602099, test error 50.65
# Epoch   700, train loss 1.009805, train error 34.32,  test loss 1.650817, test error 51.40
# Epoch   800, train loss 0.990729, train error 33.65,  test loss 1.698747, test error 50.67
# Epoch   900, train loss 0.985434, train error 33.93,  test loss 1.765375, test error 52.03
# Training model with  26 hidden variables
# Epoch     0, train loss 2.199557, train error 80.85,  test loss 2.166076, test error 79.85
# Epoch   100, train loss 1.195270, train error 39.62,  test loss 1.364145, test error 49.60
# Epoch   200, train loss 1.059463, train error 35.20,  test loss 1.479072, test error 50.12
# Epoch   300, train loss 0.986330, train error 32.50,  test loss 1.573161, test error 50.60
# Epoch   400, train loss 0.935871, train error 31.57,  test loss 1.702904, test error 51.25
# Epoch   500, train loss 0.909596, train error 30.22,  test loss 1.840153, test error 52.47
# Epoch   600, train loss 0.877892, train error 29.35,  test loss 1.902042, test error 52.75
# Epoch   700, train loss 0.884173, train error 30.22,  test loss 1.999728, test error 53.35
# Epoch   800, train loss 0.853548, train error 28.35,  test loss 2.028219, test error 52.70
# Epoch   900, train loss 0.844362, train error 27.90,  test loss 2.106194, test error 52.75
# Training model with  30 hidden variables
# Epoch     0, train loss 2.108794, train error 77.78,  test loss 2.071311, test error 78.07
# Epoch   100, train loss 1.089112, train error 36.22,  test loss 1.351776, test error 48.40
# Epoch   200, train loss 0.928200, train error 30.40,  test loss 1.532687, test error 50.47
# Epoch   300, train loss 0.868472, train error 29.88,  test loss 1.688961, test error 51.28
# Epoch   400, train loss 0.802907, train error 27.40,  test loss 1.838638, test error 50.72
# Epoch   500, train loss 0.766947, train error 26.12,  test loss 1.975082, test error 53.30
# Epoch   600, train loss 0.729945, train error 24.75,  test loss 2.098772, test error 53.53
# Epoch   700, train loss 0.702441, train error 23.72,  test loss 2.240023, test error 54.40
# Epoch   800, train loss 0.681816, train error 23.00,  test loss 2.321805, test error 53.78
# Epoch   900, train loss 0.664747, train error 23.20,  test loss 2.443970, test error 55.00
# Training model with  35 hidden variables
# Epoch     0, train loss 2.189721, train error 79.45,  test loss 2.175772, test error 80.20
# Epoch   100, train loss 1.032794, train error 33.53,  test loss 1.396926, test error 49.85
# Epoch   200, train loss 0.811100, train error 26.00,  test loss 1.699205, test error 51.30
# Epoch   300, train loss 0.696094, train error 23.57,  test loss 2.000302, test error 52.17
# Epoch   400, train loss 0.608837, train error 19.95,  test loss 2.450431, test error 54.88
# Epoch   500, train loss 0.542542, train error 18.00,  test loss 2.761760, test error 55.12
# Epoch   600, train loss 0.489335, train error 16.45,  test loss 3.110368, test error 55.55
# Epoch   700, train loss 0.467265, train error 15.72,  test loss 3.493487, test error 56.05
# Epoch   800, train loss 0.437541, train error 14.93,  test loss 3.876376, test error 56.45
# Epoch   900, train loss 0.447517, train error 15.65,  test loss 4.259230, test error 57.12
# Training model with  40 hidden variables
# Epoch     0, train loss 2.129361, train error 79.78,  test loss 2.120399, test error 79.82
# Epoch   100, train loss 0.912960, train error 28.68,  test loss 1.457733, test error 50.30
# Epoch   200, train loss 0.631214, train error 20.20,  test loss 1.933132, test error 52.67
# Epoch   300, train loss 0.496146, train error 16.38,  test loss 2.570546, test error 53.55
# Epoch   400, train loss 0.403408, train error 13.43,  test loss 3.305549, test error 55.47
# Epoch   500, train loss 0.337485, train error 11.57,  test loss 4.128305, test error 56.12
# Epoch   600, train loss 0.257046, train error 8.82,  test loss 4.959456, test error 56.67
# Epoch   700, train loss 0.255670, train error 9.05,  test loss 5.696357, test error 55.80
# Epoch   800, train loss 0.213996, train error 7.53,  test loss 6.425640, test error 57.10
# Epoch   900, train loss 0.248743, train error 9.05,  test loss 7.126603, test error 56.95
# Training model with  45 hidden variables
# Epoch     0, train loss 2.110765, train error 78.90,  test loss 2.068269, test error 78.15
# Epoch   100, train loss 0.814383, train error 25.57,  test loss 1.474206, test error 50.25
# Epoch   200, train loss 0.447842, train error 13.38,  test loss 2.220829, test error 52.35
# Epoch   300, train loss 0.323638, train error 10.62,  test loss 3.390471, test error 56.35
# Epoch   400, train loss 0.188780, train error 5.05,  test loss 4.524332, test error 55.05
# Epoch   500, train loss 0.160947, train error 5.28,  test loss 5.788647, test error 55.38
# Epoch   600, train loss 0.021975, train error 0.00,  test loss 6.953393, test error 55.80
# Epoch   700, train loss 0.011914, train error 0.00,  test loss 7.800552, test error 56.10
# Epoch   800, train loss 0.008297, train error 0.00,  test loss 8.389148, test error 55.95
# Epoch   900, train loss 0.006163, train error 0.00,  test loss 8.862898, test error 55.90
# Training model with  50 hidden variables
# Epoch     0, train loss 2.112726, train error 78.60,  test loss 2.056401, test error 77.65
# Epoch   100, train loss 0.748580, train error 22.93,  test loss 1.544988, test error 51.42
# Epoch   200, train loss 0.367307, train error 10.07,  test loss 2.551186, test error 54.38
# Epoch   300, train loss 0.192861, train error 5.05,  test loss 3.950467, test error 55.70
# Epoch   400, train loss 0.103171, train error 2.28,  test loss 5.645921, test error 56.10
# Epoch   500, train loss 0.018067, train error 0.00,  test loss 6.603932, test error 56.28
# Epoch   600, train loss 0.008350, train error 0.00,  test loss 7.330700, test error 56.17
# Epoch   700, train loss 0.005884, train error 0.00,  test loss 7.827779, test error 56.22
# Epoch   800, train loss 0.004525, train error 0.00,  test loss 8.209579, test error 56.45
# Epoch   900, train loss 0.003641, train error 0.00,  test loss 8.521355, test error 56.40
# Training model with  55 hidden variables
# Epoch     0, train loss 2.067316, train error 77.35,  test loss 2.030856, test error 77.68
# Epoch   100, train loss 0.618354, train error 19.18,  test loss 1.757243, test error 52.03
# Epoch   200, train loss 0.189344, train error 3.70,  test loss 3.074086, test error 53.65
# Epoch   300, train loss 0.037405, train error 0.05,  test loss 4.776632, test error 54.70
# Epoch   400, train loss 0.013520, train error 0.00,  test loss 5.735272, test error 54.30
# Epoch   500, train loss 0.007917, train error 0.00,  test loss 6.329517, test error 54.17
# Epoch   600, train loss 0.005446, train error 0.00,  test loss 6.752316, test error 54.38
# Epoch   700, train loss 0.004118, train error 0.00,  test loss 7.088285, test error 54.40
# Epoch   800, train loss 0.003250, train error 0.00,  test loss 7.361008, test error 54.40
# Epoch   900, train loss 0.002686, train error 0.00,  test loss 7.588703, test error 54.33
# Training model with  60 hidden variables
# Epoch     0, train loss 2.093951, train error 76.70,  test loss 2.054842, test error 76.88
# Epoch   100, train loss 0.556909, train error 16.18,  test loss 1.735018, test error 50.25
# Epoch   200, train loss 0.106217, train error 0.95,  test loss 3.205736, test error 52.85
# Epoch   300, train loss 0.020103, train error 0.00,  test loss 4.588189, test error 53.10
# Epoch   400, train loss 0.009589, train error 0.00,  test loss 5.270720, test error 53.10
# Epoch   500, train loss 0.005973, train error 0.00,  test loss 5.727185, test error 53.28
# Epoch   600, train loss 0.004283, train error 0.00,  test loss 6.048948, test error 53.28
# Epoch   700, train loss 0.003274, train error 0.00,  test loss 6.310137, test error 53.60
# Epoch   800, train loss 0.002630, train error 0.00,  test loss 6.522579, test error 53.62
# Epoch   900, train loss 0.002190, train error 0.00,  test loss 6.706380, test error 53.60
# Training model with  70 hidden variables
# Epoch     0, train loss 2.042455, train error 76.10,  test loss 2.005673, test error 76.82
# Epoch   100, train loss 0.343253, train error 8.45,  test loss 2.026685, test error 52.80
# Epoch   200, train loss 0.031454, train error 0.00,  test loss 3.751229, test error 55.17
# Epoch   300, train loss 0.011004, train error 0.00,  test loss 4.542548, test error 55.25
# Epoch   400, train loss 0.006051, train error 0.00,  test loss 4.987979, test error 55.15
# Epoch   500, train loss 0.004075, train error 0.00,  test loss 5.301505, test error 55.17
# Epoch   600, train loss 0.003019, train error 0.00,  test loss 5.540844, test error 55.35
# Epoch   700, train loss 0.002379, train error 0.00,  test loss 5.736361, test error 55.42
# Epoch   800, train loss 0.001943, train error 0.00,  test loss 5.896119, test error 55.47
# Epoch   900, train loss 0.001635, train error 0.00,  test loss 6.033155, test error 55.45
# Training model with  80 hidden variables
# Epoch     0, train loss 2.009996, train error 74.57,  test loss 1.928870, test error 74.35
# Epoch   100, train loss 0.229185, train error 4.47,  test loss 2.040005, test error 50.85
# Epoch   200, train loss 0.019555, train error 0.00,  test loss 3.410231, test error 51.80
# Epoch   300, train loss 0.007828, train error 0.00,  test loss 3.947431, test error 51.72
# Epoch   400, train loss 0.004654, train error 0.00,  test loss 4.281359, test error 51.83
# Epoch   500, train loss 0.003221, train error 0.00,  test loss 4.515473, test error 51.97
# Epoch   600, train loss 0.002432, train error 0.00,  test loss 4.696738, test error 52.03
# Epoch   700, train loss 0.001933, train error 0.00,  test loss 4.843011, test error 51.95
# Epoch   800, train loss 0.001593, train error 0.00,  test loss 4.970492, test error 51.97
# Epoch   900, train loss 0.001348, train error 0.00,  test loss 5.076538, test error 51.97
# Training model with  90 hidden variables
# Epoch     0, train loss 2.019668, train error 75.47,  test loss 1.935264, test error 75.85
# Epoch   100, train loss 0.162067, train error 1.47,  test loss 2.174145, test error 50.58
# Epoch   200, train loss 0.015958, train error 0.00,  test loss 3.337554, test error 51.53
# Epoch   300, train loss 0.006870, train error 0.00,  test loss 3.816658, test error 51.72
# Epoch   400, train loss 0.004144, train error 0.00,  test loss 4.104436, test error 51.70
# Epoch   500, train loss 0.002897, train error 0.00,  test loss 4.311428, test error 51.88
# Epoch   600, train loss 0.002192, train error 0.00,  test loss 4.474392, test error 52.15
# Epoch   700, train loss 0.001749, train error 0.00,  test loss 4.604457, test error 52.20
# Epoch   800, train loss 0.001444, train error 0.00,  test loss 4.716322, test error 52.22
# Epoch   900, train loss 0.001225, train error 0.00,  test loss 4.811532, test error 52.30
# Training model with 100 hidden variables
# Epoch     0, train loss 1.994649, train error 72.97,  test loss 1.926201, test error 73.97
# Epoch   100, train loss 0.100312, train error 0.28,  test loss 2.236094, test error 50.90
# Epoch   200, train loss 0.012511, train error 0.00,  test loss 3.119295, test error 51.35
# Epoch   300, train loss 0.005765, train error 0.00,  test loss 3.501717, test error 51.35
# Epoch   400, train loss 0.003584, train error 0.00,  test loss 3.737856, test error 51.47
# Epoch   500, train loss 0.002542, train error 0.00,  test loss 3.910321, test error 51.33
# Epoch   600, train loss 0.001946, train error 0.00,  test loss 4.046334, test error 51.33
# Epoch   700, train loss 0.001561, train error 0.00,  test loss 4.158643, test error 51.60
# Epoch   800, train loss 0.001297, train error 0.00,  test loss 4.253311, test error 51.53
# Epoch   900, train loss 0.001104, train error 0.00,  test loss 4.335523, test error 51.50
# Training model with 120 hidden variables
# Epoch     0, train loss 1.979559, train error 71.40,  test loss 1.929016, test error 73.90
# Epoch   100, train loss 0.056004, train error 0.03,  test loss 2.206055, test error 50.28
# Epoch   200, train loss 0.009731, train error 0.00,  test loss 2.824940, test error 49.97
# Epoch   300, train loss 0.004784, train error 0.00,  test loss 3.109074, test error 49.95
# Epoch   400, train loss 0.003047, train error 0.00,  test loss 3.293003, test error 50.10
# Epoch   500, train loss 0.002192, train error 0.00,  test loss 3.426633, test error 50.05
# Epoch   600, train loss 0.001690, train error 0.00,  test loss 3.532715, test error 50.10
# Epoch   700, train loss 0.001366, train error 0.00,  test loss 3.621144, test error 50.08
# Epoch   800, train loss 0.001139, train error 0.00,  test loss 3.695765, test error 50.15
# Epoch   900, train loss 0.000973, train error 0.00,  test loss 3.760779, test error 50.20
# Training model with 140 hidden variables
# Epoch     0, train loss 1.958978, train error 71.85,  test loss 1.879523, test error 72.75
# Epoch   100, train loss 0.034566, train error 0.00,  test loss 2.246496, test error 50.45
# Epoch   200, train loss 0.008044, train error 0.00,  test loss 2.727530, test error 50.10
# Epoch   300, train loss 0.004152, train error 0.00,  test loss 2.957805, test error 50.28
# Epoch   400, train loss 0.002704, train error 0.00,  test loss 3.110030, test error 50.33
# Epoch   500, train loss 0.001969, train error 0.00,  test loss 3.224627, test error 50.40
# Epoch   600, train loss 0.001532, train error 0.00,  test loss 3.315956, test error 50.38
# Epoch   700, train loss 0.001245, train error 0.00,  test loss 3.390886, test error 50.38
# Epoch   800, train loss 0.001044, train error 0.00,  test loss 3.455397, test error 50.40
# Epoch   900, train loss 0.000895, train error 0.00,  test loss 3.510853, test error 50.38
# Training model with 160 hidden variables
# Epoch     0, train loss 1.955024, train error 72.22,  test loss 1.884909, test error 73.15
# Epoch   100, train loss 0.028204, train error 0.00,  test loss 2.051343, test error 49.20
# Epoch   200, train loss 0.007163, train error 0.00,  test loss 2.432525, test error 49.03
# Epoch   300, train loss 0.003761, train error 0.00,  test loss 2.623122, test error 49.35
# Epoch   400, train loss 0.002471, train error 0.00,  test loss 2.751161, test error 49.22
# Epoch   500, train loss 0.001810, train error 0.00,  test loss 2.846104, test error 49.30
# Epoch   600, train loss 0.001413, train error 0.00,  test loss 2.922793, test error 49.22
# Epoch   700, train loss 0.001151, train error 0.00,  test loss 2.986332, test error 49.25
# Epoch   800, train loss 0.000967, train error 0.00,  test loss 3.040370, test error 49.17
# Epoch   900, train loss 0.000830, train error 0.00,  test loss 3.088856, test error 49.12
# Training model with 180 hidden variables
# Epoch     0, train loss 1.908504, train error 70.03,  test loss 1.851538, test error 73.00
# Epoch   100, train loss 0.024176, train error 0.00,  test loss 1.965352, test error 48.00
# Epoch   200, train loss 0.006548, train error 0.00,  test loss 2.300337, test error 48.40
# Epoch   300, train loss 0.003515, train error 0.00,  test loss 2.469191, test error 48.25
# Epoch   400, train loss 0.002334, train error 0.00,  test loss 2.582306, test error 48.10
# Epoch   500, train loss 0.001718, train error 0.00,  test loss 2.667106, test error 48.17
# Epoch   600, train loss 0.001347, train error 0.00,  test loss 2.735101, test error 48.17
# Epoch   700, train loss 0.001100, train error 0.00,  test loss 2.791818, test error 48.20
# Epoch   800, train loss 0.000925, train error 0.00,  test loss 2.840633, test error 48.20
# Epoch   900, train loss 0.000795, train error 0.00,  test loss 2.883389, test error 48.17
# Training model with 200 hidden variables
# Epoch     0, train loss 1.914546, train error 69.95,  test loss 1.811089, test error 70.90
# Epoch   100, train loss 0.021125, train error 0.00,  test loss 1.978392, test error 47.72
# Epoch   200, train loss 0.006095, train error 0.00,  test loss 2.287796, test error 47.50
# Epoch   300, train loss 0.003309, train error 0.00,  test loss 2.448077, test error 47.85
# Epoch   400, train loss 0.002209, train error 0.00,  test loss 2.555486, test error 47.80
# Epoch   500, train loss 0.001632, train error 0.00,  test loss 2.636976, test error 47.65
# Epoch   600, train loss 0.001282, train error 0.00,  test loss 2.701242, test error 47.65
# Epoch   700, train loss 0.001049, train error 0.00,  test loss 2.755781, test error 47.60
# Epoch   800, train loss 0.000883, train error 0.00,  test loss 2.802678, test error 47.60
# Epoch   900, train loss 0.000760, train error 0.00,  test loss 2.843706, test error 47.60
# Training model with 250 hidden variables
# Epoch     0, train loss 1.913636, train error 70.10,  test loss 1.848403, test error 71.75
# Epoch   100, train loss 0.017033, train error 0.00,  test loss 1.927805, test error 48.33
# Epoch   200, train loss 0.005338, train error 0.00,  test loss 2.186027, test error 48.00
# Epoch   300, train loss 0.002966, train error 0.00,  test loss 2.322215, test error 48.08
# Epoch   400, train loss 0.002000, train error 0.00,  test loss 2.415030, test error 48.20
# Epoch   500, train loss 0.001488, train error 0.00,  test loss 2.485921, test error 48.12
# Epoch   600, train loss 0.001174, train error 0.00,  test loss 2.543393, test error 48.12
# Epoch   700, train loss 0.000964, train error 0.00,  test loss 2.591512, test error 48.08
# Epoch   800, train loss 0.000813, train error 0.00,  test loss 2.632881, test error 48.10
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.669328, test error 48.00
# Training model with 300 hidden variables
# Epoch     0, train loss 1.850753, train error 66.53,  test loss 1.762361, test error 68.47
# Epoch   100, train loss 0.014554, train error 0.00,  test loss 1.875115, test error 46.80
# Epoch   200, train loss 0.004817, train error 0.00,  test loss 2.102818, test error 46.95
# Epoch   300, train loss 0.002728, train error 0.00,  test loss 2.227692, test error 46.97
# Epoch   400, train loss 0.001858, train error 0.00,  test loss 2.311910, test error 47.12
# Epoch   500, train loss 0.001389, train error 0.00,  test loss 2.377673, test error 47.03
# Epoch   600, train loss 0.001101, train error 0.00,  test loss 2.430160, test error 47.08
# Epoch   700, train loss 0.000906, train error 0.00,  test loss 2.474324, test error 47.10
# Epoch   800, train loss 0.000767, train error 0.00,  test loss 2.512572, test error 47.10
# Epoch   900, train loss 0.000663, train error 0.00,  test loss 2.545987, test error 47.05
# Training model with 400 hidden variables
# Epoch     0, train loss 1.861995, train error 67.10,  test loss 1.794510, test error 69.00
# Epoch   100, train loss 0.011786, train error 0.00,  test loss 1.756090, test error 45.55
# Epoch   200, train loss 0.004193, train error 0.00,  test loss 1.930489, test error 45.83
# Epoch   300, train loss 0.002426, train error 0.00,  test loss 2.026871, test error 45.58
# Epoch   400, train loss 0.001671, train error 0.00,  test loss 2.094735, test error 45.65
# Epoch   500, train loss 0.001259, train error 0.00,  test loss 2.146622, test error 45.50
# Epoch   600, train loss 0.001002, train error 0.00,  test loss 2.188688, test error 45.45
# Epoch   700, train loss 0.000828, train error 0.00,  test loss 2.224349, test error 45.25
# Epoch   800, train loss 0.000703, train error 0.00,  test loss 2.254766, test error 45.20
# Epoch   900, train loss 0.000609, train error 0.00,  test loss 2.281336, test error 45.25

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
