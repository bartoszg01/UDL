# %% [markdown]
# <a href="https://colab.research.google.com/github/bartoszg01/UDL/blob/main/10_2_convolution_for_mnist_1d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-tepqdo5d
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-tepqdo5d
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=02005b5ae12393e41edc4e48bb2deb2db950bea6d669be9b368e31df0e316f89
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y9un63d8/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
data['x'][0]
# Out:
# array([-0.33200567, -0.47191037, -0.77869708, -1.00974083, -0.88235257,
#         0.10393481,  1.64328435,  1.65250711,  0.68307808, -0.34263752,
#        -1.52143087, -1.10398405, -0.01709391,  1.01466801,  0.62358632,
#        -0.02391367,  0.25410829,  0.86739258,  0.93541006,  1.03587403,
#         1.59348802,  1.23684166,  0.4101985 , -0.21979299,  0.09805559,
#         0.53016368,  0.52027819,  0.18998057,  0.07043655,  0.32433058,
#         0.26860835, -0.57907735, -1.09348571, -0.86458044, -0.11352963,
#         0.01950092, -0.32821415, -0.7167305 , -0.96195825, -0.89016639])

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

model = nn.Sequential(
nn.Conv1d(in_channels=1,out_channels=15,kernel_size=3,stride=2,padding='valid'),
nn.ReLU(),
nn.Conv1d(in_channels=15,out_channels=15,kernel_size=3,stride=2,padding='valid'),
nn.ReLU(),
nn.Conv1d(in_channels=15,out_channels=15,kernel_size=3,stride=2,padding='valid'),
nn.ReLU(),
nn.Flatten(),
nn.Linear(in_features=60,out_features=10)
                       )

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.049695, train error 78.68,  val loss 2.044349, percent error 79.50
# Epoch     1, train loss 1.500086, train error 59.67,  val loss 1.527203, percent error 65.10
# Epoch     2, train loss 1.382638, train error 56.83,  val loss 1.420629, percent error 61.70
# Epoch     3, train loss 1.310668, train error 54.40,  val loss 1.335631, percent error 56.80
# Epoch     4, train loss 1.310648, train error 54.33,  val loss 1.358174, percent error 57.00
# Epoch     5, train loss 1.320521, train error 55.10,  val loss 1.363399, percent error 56.40
# Epoch     6, train loss 1.111582, train error 44.88,  val loss 1.178979, percent error 47.70
# Epoch     7, train loss 1.079783, train error 44.45,  val loss 1.154472, percent error 46.80
# Epoch     8, train loss 0.976472, train error 39.90,  val loss 1.049559, percent error 40.80
# Epoch     9, train loss 0.900552, train error 36.25,  val loss 0.971125, percent error 38.40
# Epoch    10, train loss 0.902289, train error 36.25,  val loss 0.965147, percent error 37.10
# Epoch    11, train loss 0.826025, train error 33.50,  val loss 0.906920, percent error 35.30
# Epoch    12, train loss 0.751743, train error 29.65,  val loss 0.831162, percent error 32.80
# Epoch    13, train loss 0.775631, train error 31.68,  val loss 0.859118, percent error 34.70
# Epoch    14, train loss 0.681132, train error 27.10,  val loss 0.768207, percent error 31.20
# Epoch    15, train loss 0.743175, train error 29.30,  val loss 0.850314, percent error 34.60
# Epoch    16, train loss 0.585021, train error 23.95,  val loss 0.702644, percent error 28.00
# Epoch    17, train loss 0.546085, train error 20.68,  val loss 0.660232, percent error 23.80
# Epoch    18, train loss 0.528526, train error 20.93,  val loss 0.658379, percent error 25.50
# Epoch    19, train loss 0.470377, train error 17.57,  val loss 0.595509, percent error 22.10
# Epoch    20, train loss 0.373650, train error 13.85,  val loss 0.516642, percent error 18.70
# Epoch    21, train loss 0.375606, train error 14.38,  val loss 0.534204, percent error 19.30
# Epoch    22, train loss 0.329535, train error 11.35,  val loss 0.514799, percent error 18.50
# Epoch    23, train loss 0.303864, train error 10.20,  val loss 0.483057, percent error 15.90
# Epoch    24, train loss 0.300287, train error 11.20,  val loss 0.489815, percent error 16.70
# Epoch    25, train loss 0.272437, train error 9.47,  val loss 0.458049, percent error 16.00
# Epoch    26, train loss 0.263430, train error 8.65,  val loss 0.461750, percent error 15.20
# Epoch    27, train loss 0.245215, train error 8.75,  val loss 0.471615, percent error 15.40
# Epoch    28, train loss 0.220994, train error 6.97,  val loss 0.436536, percent error 14.20
# Epoch    29, train loss 0.225690, train error 7.80,  val loss 0.455699, percent error 15.10
# Epoch    30, train loss 0.208066, train error 7.05,  val loss 0.450058, percent error 15.30
# Epoch    31, train loss 0.200099, train error 6.93,  val loss 0.430551, percent error 13.70
# Epoch    32, train loss 0.232063, train error 8.15,  val loss 0.487245, percent error 15.60
# Epoch    33, train loss 0.182051, train error 6.10,  val loss 0.423677, percent error 13.90
# Epoch    34, train loss 0.194156, train error 6.78,  val loss 0.433441, percent error 13.20
# Epoch    35, train loss 0.248695, train error 9.30,  val loss 0.506598, percent error 15.50
# Epoch    36, train loss 0.159101, train error 5.20,  val loss 0.407697, percent error 12.00
# Epoch    37, train loss 0.149595, train error 5.28,  val loss 0.394826, percent error 11.90
# Epoch    38, train loss 0.145071, train error 5.03,  val loss 0.412929, percent error 12.10
# Epoch    39, train loss 0.148463, train error 4.70,  val loss 0.416342, percent error 12.40
# Epoch    40, train loss 0.131870, train error 4.05,  val loss 0.393710, percent error 11.90
# Epoch    41, train loss 0.132637, train error 4.38,  val loss 0.410190, percent error 11.70
# Epoch    42, train loss 0.121859, train error 3.85,  val loss 0.403407, percent error 11.90
# Epoch    43, train loss 0.132845, train error 4.70,  val loss 0.416345, percent error 11.30
# Epoch    44, train loss 0.119724, train error 3.80,  val loss 0.410011, percent error 11.30
# Epoch    45, train loss 0.113755, train error 3.53,  val loss 0.397807, percent error 11.40
# Epoch    46, train loss 0.123283, train error 4.22,  val loss 0.424531, percent error 12.30
# Epoch    47, train loss 0.115785, train error 3.82,  val loss 0.425389, percent error 12.00
# Epoch    48, train loss 0.100757, train error 2.88,  val loss 0.408352, percent error 11.10
# Epoch    49, train loss 0.108607, train error 3.65,  val loss 0.415773, percent error 12.00
# Epoch    50, train loss 0.102312, train error 2.93,  val loss 0.419651, percent error 10.40
# Epoch    51, train loss 0.104476, train error 3.18,  val loss 0.426871, percent error 11.40
# Epoch    52, train loss 0.103189, train error 3.22,  val loss 0.419951, percent error 10.60
# Epoch    53, train loss 0.104282, train error 3.43,  val loss 0.433698, percent error 11.70
# Epoch    54, train loss 0.092566, train error 2.70,  val loss 0.406613, percent error 10.60
# Epoch    55, train loss 0.097789, train error 2.97,  val loss 0.436692, percent error 12.20
# Epoch    56, train loss 0.092313, train error 2.32,  val loss 0.424201, percent error 11.60
# Epoch    57, train loss 0.090901, train error 2.53,  val loss 0.424931, percent error 11.20
# Epoch    58, train loss 0.085902, train error 2.43,  val loss 0.427144, percent error 11.60
# Epoch    59, train loss 0.090102, train error 2.70,  val loss 0.415368, percent error 10.00
# Epoch    60, train loss 0.080752, train error 2.05,  val loss 0.427578, percent error 10.90
# Epoch    61, train loss 0.076524, train error 1.88,  val loss 0.423926, percent error 11.20
# Epoch    62, train loss 0.076607, train error 2.05,  val loss 0.416306, percent error 10.90
# Epoch    63, train loss 0.075725, train error 2.07,  val loss 0.434116, percent error 11.60
# Epoch    64, train loss 0.077643, train error 1.95,  val loss 0.431447, percent error 11.20
# Epoch    65, train loss 0.075782, train error 2.07,  val loss 0.429643, percent error 11.00
# Epoch    66, train loss 0.075839, train error 2.00,  val loss 0.434931, percent error 11.00
# Epoch    67, train loss 0.072389, train error 1.95,  val loss 0.429079, percent error 10.70
# Epoch    68, train loss 0.071808, train error 1.80,  val loss 0.425692, percent error 11.00
# Epoch    69, train loss 0.069059, train error 1.50,  val loss 0.427677, percent error 10.70
# Epoch    70, train loss 0.069817, train error 1.80,  val loss 0.442352, percent error 11.10
# Epoch    71, train loss 0.068846, train error 1.78,  val loss 0.430291, percent error 10.90
# Epoch    72, train loss 0.068351, train error 1.62,  val loss 0.435169, percent error 10.70
# Epoch    73, train loss 0.074067, train error 2.03,  val loss 0.440849, percent error 11.10
# Epoch    74, train loss 0.067032, train error 1.50,  val loss 0.438270, percent error 10.70
# Epoch    75, train loss 0.068077, train error 1.62,  val loss 0.444053, percent error 11.10
# Epoch    76, train loss 0.065036, train error 1.57,  val loss 0.439942, percent error 10.70
# Epoch    77, train loss 0.065009, train error 1.50,  val loss 0.445189, percent error 11.10
# Epoch    78, train loss 0.066466, train error 1.65,  val loss 0.453039, percent error 11.40
# Epoch    79, train loss 0.065627, train error 1.53,  val loss 0.440207, percent error 11.00
# Epoch    80, train loss 0.061488, train error 1.35,  val loss 0.443916, percent error 11.20
# Epoch    81, train loss 0.061393, train error 1.38,  val loss 0.448300, percent error 11.40
# Epoch    82, train loss 0.070436, train error 1.70,  val loss 0.455279, percent error 11.30
# Epoch    83, train loss 0.060563, train error 1.32,  val loss 0.445870, percent error 10.80
# Epoch    84, train loss 0.060301, train error 1.25,  val loss 0.441313, percent error 10.60
# Epoch    85, train loss 0.059660, train error 1.22,  val loss 0.444077, percent error 10.90
# Epoch    86, train loss 0.059715, train error 1.22,  val loss 0.444996, percent error 10.70
# Epoch    87, train loss 0.059858, train error 1.25,  val loss 0.443510, percent error 10.70
# Epoch    88, train loss 0.059632, train error 1.38,  val loss 0.449382, percent error 10.90
# Epoch    89, train loss 0.059057, train error 1.12,  val loss 0.450273, percent error 10.90
# Epoch    90, train loss 0.058442, train error 1.18,  val loss 0.449753, percent error 10.80
# Epoch    91, train loss 0.058027, train error 1.20,  val loss 0.451180, percent error 11.00
# Epoch    92, train loss 0.057527, train error 1.18,  val loss 0.449233, percent error 10.60
# Epoch    93, train loss 0.058170, train error 1.18,  val loss 0.447579, percent error 11.00
# Epoch    94, train loss 0.056724, train error 1.18,  val loss 0.453898, percent error 10.90
# Epoch    95, train loss 0.056877, train error 1.12,  val loss 0.453123, percent error 11.00
# Epoch    96, train loss 0.056741, train error 1.20,  val loss 0.454765, percent error 11.00
# Epoch    97, train loss 0.056192, train error 1.15,  val loss 0.453222, percent error 11.00
# Epoch    98, train loss 0.056487, train error 1.12,  val loss 0.453298, percent error 10.90
# Epoch    99, train loss 0.055702, train error 1.15,  val loss 0.454770, percent error 11.00
