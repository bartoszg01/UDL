# %% [markdown]
# <a href="https://colab.research.google.com/github/bartoszg01/UDL/blob/main/11_2_residual_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-vtvwris4
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-vtvwris4
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=4c7adc1268ed73aa27365f7522a8d1d8cc05f5fce2c992f1e81a1c8d2f366a95
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dchvihzl/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  # def forward(self, x):
  #   h1 = self.linear1(x).relu()
  #   h2 = self.linear2(h1).relu()
  #   h3 = self.linear3(h2).relu()
  #   return self.linear4(h3)
  def forward(self, x):
    h1 = self.linear1(x)
    h2 = self.linear2(h1.relu()) + h1
    h3 = self.linear3(h2.relu()) + h2
    return self.linear4(h3)

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10

class Network(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(Network, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

  def forward(self, x):
    h1 = self.linear1(x).relu()
    h2 = self.linear2(h1).relu()
    h3 = self.linear3(h2).relu()
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.539638, train error 57.85,  val loss 1.694800, percent error 66.10
# Epoch     1, train loss 1.137961, train error 43.50,  val loss 1.248098, percent error 50.10
# Epoch     2, train loss 1.015527, train error 38.53,  val loss 1.225487, percent error 47.50
# Epoch     3, train loss 0.906655, train error 34.72,  val loss 1.154997, percent error 45.70
# Epoch     4, train loss 0.867329, train error 33.18,  val loss 1.125332, percent error 44.70
# Epoch     5, train loss 0.767745, train error 28.95,  val loss 1.110791, percent error 43.10
# Epoch     6, train loss 0.748391, train error 27.72,  val loss 1.149560, percent error 41.70
# Epoch     7, train loss 0.680768, train error 26.03,  val loss 1.140271, percent error 40.10
# Epoch     8, train loss 0.575512, train error 21.90,  val loss 1.133882, percent error 39.10
# Epoch     9, train loss 0.527121, train error 20.47,  val loss 1.124960, percent error 38.20
# Epoch    10, train loss 0.509541, train error 19.38,  val loss 1.171896, percent error 37.70
# Epoch    11, train loss 0.499850, train error 17.88,  val loss 1.285318, percent error 37.30
# Epoch    12, train loss 0.430627, train error 16.22,  val loss 1.285023, percent error 38.40
# Epoch    13, train loss 0.392509, train error 14.82,  val loss 1.259914, percent error 36.00
# Epoch    14, train loss 0.378937, train error 13.97,  val loss 1.305853, percent error 36.40
# Epoch    15, train loss 0.351159, train error 13.07,  val loss 1.338890, percent error 37.10
# Epoch    16, train loss 0.302538, train error 10.93,  val loss 1.298724, percent error 32.60
# Epoch    17, train loss 0.304220, train error 11.28,  val loss 1.399293, percent error 35.40
# Epoch    18, train loss 0.292669, train error 10.85,  val loss 1.526931, percent error 35.70
# Epoch    19, train loss 0.276662, train error 9.95,  val loss 1.430852, percent error 34.90
# Epoch    20, train loss 0.069695, train error 1.65,  val loss 1.298658, percent error 31.30
# Epoch    21, train loss 0.037504, train error 0.30,  val loss 1.271902, percent error 31.30
# Epoch    22, train loss 0.023193, train error 0.05,  val loss 1.318565, percent error 30.10
# Epoch    23, train loss 0.017174, train error 0.00,  val loss 1.358350, percent error 29.90
# Epoch    24, train loss 0.013264, train error 0.00,  val loss 1.382843, percent error 30.40
# Epoch    25, train loss 0.011337, train error 0.00,  val loss 1.407527, percent error 30.40
# Epoch    26, train loss 0.009489, train error 0.00,  val loss 1.436447, percent error 30.20
# Epoch    27, train loss 0.008497, train error 0.00,  val loss 1.457036, percent error 29.60
# Epoch    28, train loss 0.007509, train error 0.00,  val loss 1.479499, percent error 29.80
# Epoch    29, train loss 0.006802, train error 0.00,  val loss 1.494365, percent error 29.80
# Epoch    30, train loss 0.006197, train error 0.00,  val loss 1.515961, percent error 30.30
# Epoch    31, train loss 0.005684, train error 0.00,  val loss 1.529040, percent error 30.10
# Epoch    32, train loss 0.005270, train error 0.00,  val loss 1.542035, percent error 29.90
# Epoch    33, train loss 0.004916, train error 0.00,  val loss 1.558225, percent error 29.90
# Epoch    34, train loss 0.004593, train error 0.00,  val loss 1.570345, percent error 29.80
# Epoch    35, train loss 0.004311, train error 0.00,  val loss 1.585907, percent error 29.60
# Epoch    36, train loss 0.004063, train error 0.00,  val loss 1.596412, percent error 29.80
# Epoch    37, train loss 0.003834, train error 0.00,  val loss 1.612303, percent error 29.70
# Epoch    38, train loss 0.003632, train error 0.00,  val loss 1.620332, percent error 29.50
# Epoch    39, train loss 0.003455, train error 0.00,  val loss 1.631811, percent error 29.50
# Epoch    40, train loss 0.003365, train error 0.00,  val loss 1.637341, percent error 29.40
# Epoch    41, train loss 0.003285, train error 0.00,  val loss 1.641045, percent error 29.50
# Epoch    42, train loss 0.003211, train error 0.00,  val loss 1.646684, percent error 29.50
# Epoch    43, train loss 0.003139, train error 0.00,  val loss 1.650397, percent error 29.60
# Epoch    44, train loss 0.003069, train error 0.00,  val loss 1.655247, percent error 29.50
# Epoch    45, train loss 0.003004, train error 0.00,  val loss 1.660519, percent error 29.60
# Epoch    46, train loss 0.002941, train error 0.00,  val loss 1.664765, percent error 29.60
# Epoch    47, train loss 0.002881, train error 0.00,  val loss 1.667453, percent error 29.90
# Epoch    48, train loss 0.002821, train error 0.00,  val loss 1.673449, percent error 29.70
# Epoch    49, train loss 0.002765, train error 0.00,  val loss 1.677354, percent error 29.80
# Epoch    50, train loss 0.002710, train error 0.00,  val loss 1.681153, percent error 29.70
# Epoch    51, train loss 0.002657, train error 0.00,  val loss 1.685785, percent error 29.70
# Epoch    52, train loss 0.002609, train error 0.00,  val loss 1.688582, percent error 29.70
# Epoch    53, train loss 0.002559, train error 0.00,  val loss 1.692297, percent error 29.80
# Epoch    54, train loss 0.002512, train error 0.00,  val loss 1.696946, percent error 29.70
# Epoch    55, train loss 0.002466, train error 0.00,  val loss 1.701212, percent error 29.80
# Epoch    56, train loss 0.002422, train error 0.00,  val loss 1.704584, percent error 29.70
# Epoch    57, train loss 0.002380, train error 0.00,  val loss 1.707843, percent error 29.70
# Epoch    58, train loss 0.002339, train error 0.00,  val loss 1.711053, percent error 29.70
# Epoch    59, train loss 0.002299, train error 0.00,  val loss 1.715165, percent error 29.70
# Epoch    60, train loss 0.002279, train error 0.00,  val loss 1.716681, percent error 29.80
# Epoch    61, train loss 0.002260, train error 0.00,  val loss 1.718535, percent error 29.70
# Epoch    62, train loss 0.002241, train error 0.00,  val loss 1.720845, percent error 29.60
# Epoch    63, train loss 0.002223, train error 0.00,  val loss 1.722214, percent error 29.60
# Epoch    64, train loss 0.002205, train error 0.00,  val loss 1.724367, percent error 29.60
# Epoch    65, train loss 0.002187, train error 0.00,  val loss 1.725604, percent error 29.60
# Epoch    66, train loss 0.002169, train error 0.00,  val loss 1.727581, percent error 29.70
# Epoch    67, train loss 0.002152, train error 0.00,  val loss 1.728958, percent error 29.60
# Epoch    68, train loss 0.002135, train error 0.00,  val loss 1.731001, percent error 29.50
# Epoch    69, train loss 0.002118, train error 0.00,  val loss 1.732487, percent error 29.70
# Epoch    70, train loss 0.002102, train error 0.00,  val loss 1.734269, percent error 29.70
# Epoch    71, train loss 0.002086, train error 0.00,  val loss 1.735643, percent error 29.70
# Epoch    72, train loss 0.002070, train error 0.00,  val loss 1.737375, percent error 29.60
# Epoch    73, train loss 0.002054, train error 0.00,  val loss 1.739214, percent error 29.60
# Epoch    74, train loss 0.002038, train error 0.00,  val loss 1.740673, percent error 29.60
# Epoch    75, train loss 0.002023, train error 0.00,  val loss 1.742292, percent error 29.70
# Epoch    76, train loss 0.002008, train error 0.00,  val loss 1.743931, percent error 29.70
# Epoch    77, train loss 0.001993, train error 0.00,  val loss 1.744966, percent error 29.60
# Epoch    78, train loss 0.001978, train error 0.00,  val loss 1.746978, percent error 29.60
# Epoch    79, train loss 0.001964, train error 0.00,  val loss 1.748480, percent error 29.60
# Epoch    80, train loss 0.001956, train error 0.00,  val loss 1.749318, percent error 29.60
# Epoch    81, train loss 0.001949, train error 0.00,  val loss 1.749950, percent error 29.60
# Epoch    82, train loss 0.001942, train error 0.00,  val loss 1.750719, percent error 29.60
# Epoch    83, train loss 0.001935, train error 0.00,  val loss 1.751309, percent error 29.60
# Epoch    84, train loss 0.001928, train error 0.00,  val loss 1.752227, percent error 29.60
# Epoch    85, train loss 0.001921, train error 0.00,  val loss 1.752870, percent error 29.60
# Epoch    86, train loss 0.001915, train error 0.00,  val loss 1.753982, percent error 29.60
# Epoch    87, train loss 0.001908, train error 0.00,  val loss 1.754613, percent error 29.60
# Epoch    88, train loss 0.001901, train error 0.00,  val loss 1.755258, percent error 29.60
# Epoch    89, train loss 0.001894, train error 0.00,  val loss 1.756118, percent error 29.60
# Epoch    90, train loss 0.001888, train error 0.00,  val loss 1.756905, percent error 29.60
# Epoch    91, train loss 0.001881, train error 0.00,  val loss 1.757466, percent error 29.60
# Epoch    92, train loss 0.001874, train error 0.00,  val loss 1.758036, percent error 29.60
# Epoch    93, train loss 0.001868, train error 0.00,  val loss 1.758864, percent error 29.60
# Epoch    94, train loss 0.001861, train error 0.00,  val loss 1.759700, percent error 29.60
# Epoch    95, train loss 0.001855, train error 0.00,  val loss 1.760535, percent error 29.60
# Epoch    96, train loss 0.001848, train error 0.00,  val loss 1.761070, percent error 29.60
# Epoch    97, train loss 0.001842, train error 0.00,  val loss 1.761871, percent error 29.50
# Epoch    98, train loss 0.001836, train error 0.00,  val loss 1.762708, percent error 29.50
# Epoch    99, train loss 0.001829, train error 0.00,  val loss 1.763465, percent error 29.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?

# %%
#Define the model
model = Network(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.584764, train error 59.60,  val loss 1.661829, percent error 66.80
# Epoch     1, train loss 1.357937, train error 51.62,  val loss 1.492751, percent error 61.80
# Epoch     2, train loss 1.194973, train error 43.97,  val loss 1.392324, percent error 52.40
# Epoch     3, train loss 1.033854, train error 38.17,  val loss 1.305444, percent error 51.30
# Epoch     4, train loss 0.875883, train error 32.15,  val loss 1.192191, percent error 46.50
# Epoch     5, train loss 0.748163, train error 26.18,  val loss 1.138126, percent error 43.60
# Epoch     6, train loss 0.679917, train error 24.32,  val loss 1.164827, percent error 44.60
# Epoch     7, train loss 0.613029, train error 22.03,  val loss 1.162516, percent error 42.60
# Epoch     8, train loss 0.469901, train error 15.57,  val loss 1.085756, percent error 40.20
# Epoch     9, train loss 0.396516, train error 13.20,  val loss 1.092884, percent error 39.90
# Epoch    10, train loss 0.376180, train error 12.65,  val loss 1.110548, percent error 38.40
# Epoch    11, train loss 0.304832, train error 9.43,  val loss 1.077777, percent error 35.30
# Epoch    12, train loss 0.291591, train error 10.72,  val loss 1.234300, percent error 38.60
# Epoch    13, train loss 0.214074, train error 6.18,  val loss 1.196294, percent error 35.80
# Epoch    14, train loss 0.210493, train error 6.60,  val loss 1.320271, percent error 37.50
# Epoch    15, train loss 0.220278, train error 7.28,  val loss 1.317423, percent error 37.40
# Epoch    16, train loss 0.178641, train error 5.53,  val loss 1.401912, percent error 37.10
# Epoch    17, train loss 0.121676, train error 3.65,  val loss 1.242305, percent error 33.30
# Epoch    18, train loss 0.090613, train error 2.10,  val loss 1.342400, percent error 34.40
# Epoch    19, train loss 0.101534, train error 3.12,  val loss 1.480642, percent error 35.10
# Epoch    20, train loss 0.027707, train error 0.10,  val loss 1.356148, percent error 33.40
# Epoch    21, train loss 0.016019, train error 0.00,  val loss 1.349751, percent error 32.30
# Epoch    22, train loss 0.011598, train error 0.00,  val loss 1.378561, percent error 32.00
# Epoch    23, train loss 0.009796, train error 0.00,  val loss 1.407013, percent error 32.00
# Epoch    24, train loss 0.008425, train error 0.00,  val loss 1.430735, percent error 32.00
# Epoch    25, train loss 0.007495, train error 0.00,  val loss 1.443870, percent error 31.90
# Epoch    26, train loss 0.006834, train error 0.00,  val loss 1.461386, percent error 32.00
# Epoch    27, train loss 0.006250, train error 0.00,  val loss 1.481063, percent error 32.00
# Epoch    28, train loss 0.005701, train error 0.00,  val loss 1.500568, percent error 32.10
# Epoch    29, train loss 0.005281, train error 0.00,  val loss 1.512972, percent error 32.30
# Epoch    30, train loss 0.004931, train error 0.00,  val loss 1.523268, percent error 32.40
# Epoch    31, train loss 0.004616, train error 0.00,  val loss 1.540404, percent error 32.20
# Epoch    32, train loss 0.004359, train error 0.00,  val loss 1.551148, percent error 32.50
# Epoch    33, train loss 0.004110, train error 0.00,  val loss 1.564063, percent error 32.20
# Epoch    34, train loss 0.003895, train error 0.00,  val loss 1.573927, percent error 32.20
# Epoch    35, train loss 0.003698, train error 0.00,  val loss 1.583246, percent error 32.00
# Epoch    36, train loss 0.003522, train error 0.00,  val loss 1.595148, percent error 32.50
# Epoch    37, train loss 0.003385, train error 0.00,  val loss 1.606889, percent error 32.00
# Epoch    38, train loss 0.003214, train error 0.00,  val loss 1.615198, percent error 32.20
# Epoch    39, train loss 0.003087, train error 0.00,  val loss 1.619013, percent error 32.20
# Epoch    40, train loss 0.003015, train error 0.00,  val loss 1.626858, percent error 32.30
# Epoch    41, train loss 0.002954, train error 0.00,  val loss 1.631445, percent error 32.30
# Epoch    42, train loss 0.002898, train error 0.00,  val loss 1.636380, percent error 32.40
# Epoch    43, train loss 0.002843, train error 0.00,  val loss 1.640695, percent error 32.40
# Epoch    44, train loss 0.002791, train error 0.00,  val loss 1.644919, percent error 32.40
# Epoch    45, train loss 0.002739, train error 0.00,  val loss 1.649558, percent error 32.40
# Epoch    46, train loss 0.002689, train error 0.00,  val loss 1.653143, percent error 32.40
# Epoch    47, train loss 0.002641, train error 0.00,  val loss 1.656075, percent error 32.30
# Epoch    48, train loss 0.002597, train error 0.00,  val loss 1.660629, percent error 32.30
# Epoch    49, train loss 0.002552, train error 0.00,  val loss 1.663928, percent error 32.40
# Epoch    50, train loss 0.002509, train error 0.00,  val loss 1.668089, percent error 32.30
# Epoch    51, train loss 0.002467, train error 0.00,  val loss 1.671536, percent error 32.30
# Epoch    52, train loss 0.002427, train error 0.00,  val loss 1.673980, percent error 32.40
# Epoch    53, train loss 0.002390, train error 0.00,  val loss 1.677363, percent error 32.50
# Epoch    54, train loss 0.002350, train error 0.00,  val loss 1.682600, percent error 32.20
# Epoch    55, train loss 0.002314, train error 0.00,  val loss 1.684348, percent error 32.30
# Epoch    56, train loss 0.002278, train error 0.00,  val loss 1.688514, percent error 32.50
# Epoch    57, train loss 0.002243, train error 0.00,  val loss 1.692752, percent error 32.20
# Epoch    58, train loss 0.002210, train error 0.00,  val loss 1.695643, percent error 32.20
# Epoch    59, train loss 0.002178, train error 0.00,  val loss 1.699264, percent error 32.20
# Epoch    60, train loss 0.002161, train error 0.00,  val loss 1.700808, percent error 32.20
# Epoch    61, train loss 0.002145, train error 0.00,  val loss 1.702440, percent error 32.20
# Epoch    62, train loss 0.002130, train error 0.00,  val loss 1.704289, percent error 32.30
# Epoch    63, train loss 0.002114, train error 0.00,  val loss 1.705517, percent error 32.40
# Epoch    64, train loss 0.002100, train error 0.00,  val loss 1.707678, percent error 32.30
# Epoch    65, train loss 0.002085, train error 0.00,  val loss 1.709182, percent error 32.30
# Epoch    66, train loss 0.002070, train error 0.00,  val loss 1.710717, percent error 32.30
# Epoch    67, train loss 0.002056, train error 0.00,  val loss 1.712386, percent error 32.40
# Epoch    68, train loss 0.002042, train error 0.00,  val loss 1.714245, percent error 32.20
# Epoch    69, train loss 0.002028, train error 0.00,  val loss 1.715380, percent error 32.30
# Epoch    70, train loss 0.002014, train error 0.00,  val loss 1.716424, percent error 32.30
# Epoch    71, train loss 0.002000, train error 0.00,  val loss 1.718391, percent error 32.30
# Epoch    72, train loss 0.001987, train error 0.00,  val loss 1.719694, percent error 32.20
# Epoch    73, train loss 0.001973, train error 0.00,  val loss 1.721486, percent error 32.20
# Epoch    74, train loss 0.001960, train error 0.00,  val loss 1.723235, percent error 32.20
# Epoch    75, train loss 0.001947, train error 0.00,  val loss 1.725050, percent error 32.10
# Epoch    76, train loss 0.001934, train error 0.00,  val loss 1.725881, percent error 32.10
# Epoch    77, train loss 0.001922, train error 0.00,  val loss 1.727372, percent error 32.20
# Epoch    78, train loss 0.001909, train error 0.00,  val loss 1.728965, percent error 32.10
# Epoch    79, train loss 0.001897, train error 0.00,  val loss 1.730373, percent error 32.20
# Epoch    80, train loss 0.001891, train error 0.00,  val loss 1.730973, percent error 32.10
# Epoch    81, train loss 0.001885, train error 0.00,  val loss 1.731717, percent error 32.20
# Epoch    82, train loss 0.001879, train error 0.00,  val loss 1.732404, percent error 32.10
# Epoch    83, train loss 0.001873, train error 0.00,  val loss 1.732982, percent error 32.20
# Epoch    84, train loss 0.001867, train error 0.00,  val loss 1.733765, percent error 32.20
# Epoch    85, train loss 0.001861, train error 0.00,  val loss 1.734269, percent error 32.10
# Epoch    86, train loss 0.001855, train error 0.00,  val loss 1.735212, percent error 32.10
# Epoch    87, train loss 0.001849, train error 0.00,  val loss 1.735646, percent error 32.20
# Epoch    88, train loss 0.001843, train error 0.00,  val loss 1.736426, percent error 32.20
# Epoch    89, train loss 0.001838, train error 0.00,  val loss 1.737174, percent error 32.10
# Epoch    90, train loss 0.001832, train error 0.00,  val loss 1.737696, percent error 32.20
# Epoch    91, train loss 0.001826, train error 0.00,  val loss 1.738657, percent error 32.30
# Epoch    92, train loss 0.001821, train error 0.00,  val loss 1.739161, percent error 32.20
# Epoch    93, train loss 0.001815, train error 0.00,  val loss 1.740143, percent error 32.20
# Epoch    94, train loss 0.001809, train error 0.00,  val loss 1.740811, percent error 32.20
# Epoch    95, train loss 0.001804, train error 0.00,  val loss 1.741124, percent error 32.30
# Epoch    96, train loss 0.001798, train error 0.00,  val loss 1.741981, percent error 32.20
# Epoch    97, train loss 0.001793, train error 0.00,  val loss 1.742805, percent error 32.30
# Epoch    98, train loss 0.001787, train error 0.00,  val loss 1.743366, percent error 32.30
# Epoch    99, train loss 0.001782, train error 0.00,  val loss 1.743876, percent error 32.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()
