# %% [markdown]
# <a href="https://colab.research.google.com/github/bartoszg01/UDL/blob/main/8_1_mnist_1d_performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-9os1b8tb
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-9os1b8tb
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=46707039a19a5b6680c36bc00c2ada1c3ccf2be8f856d738c4aafe995a4ea875
#   Stored in directory: /tmp/pip-ephem-wheel-cache-06ift67x/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o)
    );


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=10, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.424781, train error 55.00,  test loss 1.558958, test error 62.20
# Epoch     1, train loss 1.186712, train error 45.30,  test loss 1.376696, test error 53.60
# Epoch     2, train loss 0.956227, train error 35.03,  test loss 1.234824, test error 46.10
# Epoch     3, train loss 0.835784, train error 30.55,  test loss 1.135523, test error 44.10
# Epoch     4, train loss 0.760493, train error 27.97,  test loss 1.132404, test error 40.90
# Epoch     5, train loss 0.654275, train error 23.28,  test loss 1.060493, test error 39.80
# Epoch     6, train loss 0.600967, train error 22.80,  test loss 1.132160, test error 41.90
# Epoch     7, train loss 0.462661, train error 16.35,  test loss 1.078630, test error 39.40
# Epoch     8, train loss 0.417464, train error 14.85,  test loss 1.053973, test error 37.20
# Epoch     9, train loss 0.443346, train error 16.10,  test loss 1.154366, test error 38.30
# Epoch    10, train loss 0.210205, train error 5.82,  test loss 0.985283, test error 33.50
# Epoch    11, train loss 0.159179, train error 3.47,  test loss 0.974982, test error 33.10
# Epoch    12, train loss 0.133272, train error 2.62,  test loss 1.022135, test error 34.00
# Epoch    13, train loss 0.112241, train error 2.03,  test loss 1.089801, test error 33.90
# Epoch    14, train loss 0.086853, train error 1.03,  test loss 1.098171, test error 32.90
# Epoch    15, train loss 0.067681, train error 0.47,  test loss 1.142567, test error 33.90
# Epoch    16, train loss 0.056925, train error 0.18,  test loss 1.183666, test error 33.40
# Epoch    17, train loss 0.048160, train error 0.15,  test loss 1.200857, test error 34.20
# Epoch    18, train loss 0.039309, train error 0.10,  test loss 1.205425, test error 33.60
# Epoch    19, train loss 0.032395, train error 0.00,  test loss 1.260646, test error 34.00
# Epoch    20, train loss 0.026819, train error 0.00,  test loss 1.263287, test error 34.80
# Epoch    21, train loss 0.024932, train error 0.00,  test loss 1.266875, test error 34.10
# Epoch    22, train loss 0.023564, train error 0.00,  test loss 1.275930, test error 34.80
# Epoch    23, train loss 0.022009, train error 0.00,  test loss 1.288156, test error 34.60
# Epoch    24, train loss 0.020916, train error 0.00,  test loss 1.301064, test error 34.00
# Epoch    25, train loss 0.019852, train error 0.00,  test loss 1.313717, test error 33.90
# Epoch    26, train loss 0.018753, train error 0.00,  test loss 1.317958, test error 34.50
# Epoch    27, train loss 0.017977, train error 0.00,  test loss 1.335007, test error 33.80
# Epoch    28, train loss 0.017292, train error 0.00,  test loss 1.336727, test error 34.00
# Epoch    29, train loss 0.016482, train error 0.00,  test loss 1.353019, test error 34.10
# Epoch    30, train loss 0.015896, train error 0.00,  test loss 1.354848, test error 34.30
# Epoch    31, train loss 0.015593, train error 0.00,  test loss 1.358165, test error 34.10
# Epoch    32, train loss 0.015264, train error 0.00,  test loss 1.362988, test error 34.20
# Epoch    33, train loss 0.014994, train error 0.00,  test loss 1.364253, test error 34.00
# Epoch    34, train loss 0.014693, train error 0.00,  test loss 1.372211, test error 34.00
# Epoch    35, train loss 0.014375, train error 0.00,  test loss 1.373958, test error 34.10
# Epoch    36, train loss 0.014123, train error 0.00,  test loss 1.380671, test error 34.10
# Epoch    37, train loss 0.013866, train error 0.00,  test loss 1.384350, test error 34.30
# Epoch    38, train loss 0.013624, train error 0.00,  test loss 1.385934, test error 34.20
# Epoch    39, train loss 0.013380, train error 0.00,  test loss 1.391351, test error 34.20
# Epoch    40, train loss 0.013232, train error 0.00,  test loss 1.392474, test error 34.30
# Epoch    41, train loss 0.013111, train error 0.00,  test loss 1.394701, test error 34.40
# Epoch    42, train loss 0.013006, train error 0.00,  test loss 1.397117, test error 34.40
# Epoch    43, train loss 0.012889, train error 0.00,  test loss 1.398814, test error 34.40
# Epoch    44, train loss 0.012778, train error 0.00,  test loss 1.400825, test error 34.40
# Epoch    45, train loss 0.012672, train error 0.00,  test loss 1.402325, test error 34.30
# Epoch    46, train loss 0.012570, train error 0.00,  test loss 1.404164, test error 34.20
# Epoch    47, train loss 0.012465, train error 0.00,  test loss 1.405705, test error 34.30
# Epoch    48, train loss 0.012365, train error 0.00,  test loss 1.407120, test error 34.30
# Epoch    49, train loss 0.012262, train error 0.00,  test loss 1.409994, test error 34.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
